# %%
from SimPy.Simulation import *
import random
import numpy as np
import math
import pandas as pd
import scipy.stats as ss
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def conf(L):
    """confidence interval"""
    lower = np.mean(L) - 1.96*np.std(L)/math.sqrt(len(L))
    upper = np.mean(L) + 1.96*np.std(L)/math.sqrt(len(L))
    return (lower, upper)

# %%
data = pd.read_csv("Cafe Louis Data.csv").iloc[:,1:]
data.head()
# Out:
#    Inter-Arrival Time  Waiting Time  Service Time
# 0                0.00          0.00         51.90
# 1               15.38         43.96         35.75
# 2               68.47          0.00         25.13
# 3               13.09          0.00         33.16
# 4               19.40         11.14         31.19

# %%
print("Mean Interarrival Time: ", np.mean(data["Inter-Arrival Time"]))
print("Mean Service Time: ", np.mean(data["Service Time"]))
# Out:
# Mean Interarrival Time:  27.674940239043824
# Mean Service Time:  41.30215139442231

# %%
exp_arrival_rate = 1/np.mean(data["Inter-Arrival Time"])
exp_service_rate = 1/np.mean(data["Service Time"])

# %%
print("Expected Arrival rate: %s, Expected Service Rate: %s, p : %s" %(exp_arrival_rate,exp_service_rate,exp_arrival_rate/exp_service_rate))
# Out:
# Expected Arrival rate: 0.03613377269697585, Expected Service Rate: 0.024211813821762466, p : 1.4924025503821399

# %% [markdown]
# ## Model 1 (M/M/c)

# %%
## Model ----------
class Source(Process):
    """generate random arrivals"""
    def run(self, N, lamb, mu):
        for i in range(N):
            a = Arrival(str(i))
            activate(a, a.run(mu))
            t = random.expovariate(lamb)
            yield hold, self, t

class Arrival(Process):
    n = 0
    """an arrival"""
    def run(self, mu):
        Arrival.n += 1
        arrivetime = now()
        G.numbermon.observe(Arrival.n)
        yield request, self, G.server
        t = random.expovariate(mu)
        yield hold, self, t
        yield release, self, G.server
        Arrival.n -= 1
        G.numbermon.observe(Arrival.n)
        delay = now()-arrivetime
        G.delaymon.observe(delay)

class G:
    server = 'dummy'
    delaymon = 'Monitor'
    numbermon = 'Monitor'

def model(c, N, lamb, mu, maxtime, rvseed):
    # setup
    initialize()
    random.seed(rvseed)
    G.server = Resource(c)
    G.delaymon = Monitor()
    G.numbermon = Monitor()
   
    # simulate
    s = Source('Source')
    activate(s, s.run(N, lamb, mu))
    simulate(until=maxtime)
   
    # gather performance measures
    W = G.delaymon.mean()
    L = G.numbermon.timeAverage()
    Lambda_eff = L/W
    return W, L, Lambda_eff

# %%
all_W = []
all_L = []
all_Lambda_eff = []
for k in range(50):
    seed = 123*k
    W, L, Lambda_eff = model(1, 10000, exp_arrival_rate, exp_service_rate, 100000, seed)
    all_W.append(W)
    all_L.append(L)
    all_Lambda_eff.append(Lambda_eff)

# %%
print("Estimate of W: ", np.mean(all_W))
print("Estimate of L: ", np.mean(all_L))
print("Estimate of Lambda_eff: ", np.mean(all_Lambda_eff))
# Out:
# Estimate of W:  16519.214184910157
# Estimate of L:  30063.44789093628
# Estimate of Lambda_eff:  1.8413316657096608

# %% [markdown]
# ## Model 2 (M/G/1)

# %% [markdown]
# Best Fit Distributions:
# - Inter-Arrival Times: Exponential loc = 27.649
# - Service Time: Erlang k = 2.12784 , loc= 5.3858, scale = 16.8792

# %%
# generating random erlang variates using estimated parameters

np.random.seed(123)

service = data["Service Time"]

fit_k,fit_loc,fit_scale = ss.erlang.fit(service)

erlang = ss.erlang(fit_k,fit_loc,fit_scale)

erlang.rvs()
# Out:
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 0.

#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.227179496435517.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.3031793377130008.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.250729285056222.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.0590900323967567.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.304792151385149.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.3310350682426115.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.2258329323171386.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.254473768368981.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.2516654058844114.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.294347496622283.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.2439714964822084.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.307786436850707.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.246321308450531.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.278391231660847.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.25834686232852.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.194300960122357.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.277169353569451.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.273337166469589.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.2530752729552956.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.281756162753303.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.253417663049982.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.264094664054632.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.2767125141607467.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.2589845832566584.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.262286402529429.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.2788758965203764.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.2810668197015618.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.2659379411647382.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.2756414076814666.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.2601300766368224.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.275832633935377.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.293444346867538.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.2675995241593783.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.2688796902813637.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.265581114146095.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.2732697539880564.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.275460766937904.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.270524959445499.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.265288084047156.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.273053076772889.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.276965669311585.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.26994106044743.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.273650968026751.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.271306461590812.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.269958440577977.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.267534221089423.
#   warnings.warn(
# ...
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1259785924331576.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.122105566640484.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1293316408173957.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1325378984815107.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.126522567031499.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.131439412328743.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.127343797407054.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1251925375433434.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1290027338563027.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.125914424712508.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1269493529931536.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.127245186303579.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1292659000817458.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1284280312394364.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.129928067234713.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1273739420823023.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.126362039227242.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1283425601990373.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1288511693769383.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.127646682071919.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1271474249960693.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.128050502762382.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1275430822523225.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1285407913527825.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1274957665852474.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.126781127073955.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1279522019177666.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1276806850983054.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1276551828285157.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1279378780804894.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.128153759632192.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.12769575159729.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.127597546148559.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1276826291315416.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1278985389358835.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1279931617261716.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1277701041295103.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1280646008572317.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1277781220629643.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.127768413137611.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1278009445871793.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1276139119353354.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.127867629422159.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1278476633629344.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1278559866892235.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.127883507740246.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.127781540032286.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.127846107074691.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.127800468566015.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1278358646637043.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1279218681555685.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1278080451360246.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1278375612695877.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1278384095725293.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1278216216551997.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.127839985719818.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1278809773163943.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.127826278181117.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.127813230091125.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.127845297539699.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1278368130241674.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1278370000855227.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.12782354511794.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.127839859434259.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1278516186452823.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1278326132971586.
#   warnings.warn(
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value array(2.12783986).
#   warnings.warn(
# 17.16237301242824

# %%
## Model ----------
class Source(Process):
    """generate random arrivals"""
    def run(self, N, lamb):
        for i in range(N):
            a = Arrival(str(i))
            activate(a, a.run())
            t = random.expovariate(lamb)
            yield hold, self, t

class Arrival(Process):
    n = 0
    """an arrival"""
    def run(self):
        Arrival.n += 1
        arrivetime = now()
        G.numbermon.observe(Arrival.n)
        yield request, self, G.server
        t = erlang.rvs() # generates random erlang variate for service time
        yield hold, self, t
        yield release, self, G.server
        Arrival.n -= 1
        G.numbermon.observe(Arrival.n)
        delay = now()-arrivetime
        G.delaymon.observe(delay)

class G:
    server = 'dummy'
    delaymon = 'Monitor'
    numbermon = 'Monitor'

def model(c, N, lamb, maxtime, rvseed):
    # setup
    initialize()
    random.seed(rvseed)
    np.random.seed(rvseed) # set random seed for scipy
    G.server = Resource(c)
    G.delaymon = Monitor()
    G.numbermon = Monitor()
   
    # simulate
    s = Source('Source')
    activate(s, s.run(N, lamb))
    simulate(until=maxtime)
   
    # gather performance measures
    W = G.delaymon
    L = G.numbermon.timeAverage()
    Lambda_eff = L/W
    return W, L, Lambda_eff

# %%
allW = []
allL = []
allLambda_eff = []
for k in range(50):
    seed = 123*k
    result_W, result_L, result_Lambda_eff = model(c=1, N=10000, lamb=exp_service_rate, maxtime=100000, rvseed=seed)
    allW.append(result_W)
    allL.append(result_L)
    allLambda_eff.append(result_Lambda_eff)
# Out:
# C:\Users\kille\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:3180: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value array(2.12783986).
#   warnings.warn(

# %%
print("Estimate of W: ", np.mean(allW))
print("Estimate of L: ", np.mean(allL))
print("Estimate of Lambda_eff: ", np.mean(allLambda_eff))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 print("Estimate of W: ", np.mean(allW))
#       2 print("Estimate of L: ", np.mean(allL))
#       3 print("Estimate of Lambda_eff: ", np.mean(allLambda_eff))
#
# File <__array_function__ internals>:200, in mean(*args, **kwargs)
#
# File c:\Python311\Lib\site-packages\numpy\core\fromnumeric.py:3464, in mean(a, axis, dtype, out, keepdims, where)
#    3461     else:
#    3462         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3464 return _methods._mean(a, axis=axis, dtype=dtype,
#    3465                       out=out, **kwargs)
#
# File c:\Python311\Lib\site-packages\numpy\core\_methods.py:165, in _mean(a, axis, dtype, out, keepdims, where)
#     164 def _mean(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
# --> 165     arr = asanyarray(a)
#     167     is_float16_result = False
#     169     rcount = _count_reduce_items(arr, axis, keepdims=keepdims, where=where)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (50,) + inhomogeneous part.

# %% [markdown]
# ## Model 3 ( Empirical Distribution)

# %%
def ecdf(data):
    n = len(data)
    x = np.sort(data)
    y = np.arange(1,n+1)/n
    return x, y

# %%
def draw_emp(data, r):
    x , y = ecdf(data)
    return np.interp(r ,y,x)

# %%
## Model ----------
class Source(Process):
    """generate random arrivals"""
    def run(self, N, lamb, mu):
        for i in range(N):
            a = Arrival(str(i))
            activate(a, a.run(mu))
            r = random.uniform(0,1)
            t = draw_emp(data['Inter-Arrival Time'], r) # generate random empirical variate for inter-arrival time from dist
            yield hold, self, t

class Arrival(Process):
    n = 0
    """an arrival"""
    def run(self, mu):
        Arrival.n += 1
        arrivetime = now()
        G.numbermon.observe(Arrival.n)
        yield request, self, G.server
        r = random.uniform(0,1)
        t = draw_emp(data["Service Time"], r) # generate random empirical variate for service time from dist
        yield hold, self, t
        yield release, self, G.server
        Arrival.n -= 1
        G.numbermon.observe(Arrival.n)
        delay = now()-arrivetime
        G.delaymon.observe(delay)

class G:
    server = 'dummy'
    delaymon = 'Monitor'
    numbermon = 'Monitor'

def model(c, N, lamb, mu, maxtime, rvseed):
    # setup
    initialize()
    random.seed(rvseed)
    G.server = Resource(c, monitored=True)
    G.delaymon = Monitor()
    G.numbermon = Monitor()
   
    # simulate
    s = Source('Source')
    activate(s, s.run(N, lamb, mu))
    simulate(until=maxtime)
   
    # gather performance measures
    W = G.delaymon.mean()
    # L
    L = G.numbermon.timeAverage()
    # Lambda_eff = l / w
    Lambda_eff = L / W
    
    
    return W, L, Lambda_eff

# %%
allW = []
allL = []
allLambda_eff = []
for k in range(50):
    seed = 123*k
    result_W, result_L, result_Lambda_eff = model(c=1,N=10000,lamb=exp_arrival_rate,mu=exp_service_rate,maxtime=10000000,rvseed=1234)
    allW.append(result_W)
    allL.append(result_L)
    allLambda_eff.append(result_Lambda_eff)

# %%
print("Estimate of W: ", np.mean(allW))

print("Estimate of L: ", np.mean(allL))

print("Estimate of Lambda_eff: ", np.mean(allLambda_eff))
# Out:
# Estimate of W:  67236.29270123183
# Estimate of L:  1654.8244356116716
# Estimate of Lambda_eff:  0.024612071384794744
